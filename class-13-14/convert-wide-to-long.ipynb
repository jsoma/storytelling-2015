# %%
import pandas as pd

# %%
df = pd.read_csv("tx.val.tech.mf.zs_Indicator_en_csv_v2.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1      Andorra          AND
# 2  Afghanistan          AFG
# 3       Angola          AGO
# 4      Albania          ALB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
# 1  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
# 2  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
# 3  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
# 4  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...        2006      2007      2008  \
# 0   NaN   NaN   NaN   NaN   NaN  ...         NaN       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   16.330524       NaN       NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...         NaN       NaN       NaN
# ...

# %%
melted = pd.melt(df, id_vars=('Country Name','Country Code','Indicator Name','Indicator Code'), var_name='Year', value_name='Percent')

# %%
melted.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1      Andorra          AND
# 2  Afghanistan          AFG
# 3       Angola          AGO
# 4      Albania          ALB
#
#                                       Indicator Name     Indicator Code  Year  \
# 0  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS  1960
# 1  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS  1960
# 2  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS  1960
# 3  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS  1960
# 4  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS  1960
#
#    Percent
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
melted.to_csv("high-tech-exports-long.csv", index=False)
